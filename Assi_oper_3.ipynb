# %% [markdown]
# # 41. What is operator precedence in Python?

# %% [raw]
# operator precedence decides which operator is evaluated first in an expression

# %%
# eg

3 + 2 * 4 
# * run first ,then + 11
# Out:
# 11

# %% [markdown]
# # 42. Which has higher precedence: and or or?

# %%
True or False and False
# and has higher precedence than or
# Out:
# True

# %% [markdown]
# # 43. What is the output of: 3 + 2 * 4 > 10 and 5 < 8?

# %%
3 + 2 * 4 > 10 and 5 < 8
""" 
2*4 = 8
3+2 = 11
11>10 = true
5<8 = true

True and True

"""
# Out:
# True

# %% [markdown]
# # 44. What is the output of: (3 + 2) * 4 > 10 or 5 < 2?

# %%
(3 + 2) * 4 > 10 or 5 < 2

# """
# 4 * 2 = 8
# 3 + 8 = 11
# 11 > 10 true
# 5 < 8 true

# true
# Out:
# True

# %% [markdown]
# # 45. What is the output of: not 3 > 2 and 5 < 10

# %%
not 3 > 2 and 5 < 10
"""
3 > 2 =True
not True = False
5 < 10 =True
False and True 
# false
"""
# Out:
# False

# %% [markdown]
# # 46. Short-Circuit Evaluation

# %% [markdown]
# short-circuit means python stops evaluating once result is decided

# %%
False and print('hello')
# and stops at false helo not printed
# Out:
# False

# %%
True or print('hello')
# or stops at true hello not printed
# Out:
# True

# %% [markdown]
# # 47. Write a program using logical operators to check if a number is between 10 and 50.

# %%
num = int(input("Enter number"))

if num > 10  and num < 50:
    print("between 10 and 50")
else:
    print("not in range")
# Out:
# Enter number 11
# between 10 and 50

# %%
age = float(input("Enter age"))

if  age>18 and age<90:
    print("eligible for vote")
    print("and driving lic")
else:
    print("not eligible for vote")
# Out:
# Enter age 23
# eligible for vote
# and driving lic

# %% [markdown]
# # 48. What is the output of: x = 5 y = 10 print(x > 3 and y < 15)?

# %%
x = 5 

y= 10 
print(x>3 and y<15)
# Out:
# True

# %% [markdown]
# # 49. What is the output of: x = 0 print(bool(x))?

# %%
x = 0
print(bool(x))
# Out:
# False

# %% [markdown]
# # 50. What is the output of: print(4 & 1)?

# %%
print(bin(4))
print(bin(1))

"""
100
100
011

"""

print
# Out:
# 0b100
# 0b1

# %% [markdown]
# # 51. Write a program to check whether a number is divisible by both 3 and 5.

# %%
num = int(input("Enter number"))

if num % 3 == 0 and num % 5 == 0:
          print("Divisible by both 3 and 5")
else:     
          print("Not divisible by both")
# Out:
# Enter number 4
# Not divisible by both

# %%
num = int(input("enter num"))

if num % 2 == 0 and num % 4 == 0:
    print("divisible by both 2 and 4")
else:
    print('not divisible by both')
# Out:
# enter num 3
# not divisible by both

# %% [markdown]
# # • 52. What is the output of: print(True + True)?

# %%
True + True
# Out:
# 2

# %% [markdown]
# # • 53. What is the output of: print(False * 10)?

# %%
print(False*10)
# Out:
# 0

# %% [markdown]
# # • 54. What is the output of: print(5 == 5.0)?

# %%
print(5==5.0)
# check values equal
# Out:
# True

# %% [markdown]
# # • 55. What is the output of: print(5 is 5.0)?

# %%
print(5 is 5.0)
# diff object int vs float
# Out:
# False
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15040\3611934553.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(5 is 5.0)

# %% [markdown]
# # 56. Write a program to calculate simple interest using arithmetic operators.

# %%
p = float(input("principal"))
r= float(input("rate:"))
t= float(input("time"))

simple = (p*r*t)/100
print(f"simple interet ={simple}")



# si = (p*r*n)/100
# Out:
# principal 23
# rate: 44
# time 5
# simple interet =50.6

# %% [markdown]
# # 57. Program: Area of Circle

# %%
# area = pie r squre

r = float(input("Enter radius"))
area = 3.14 * r**2
print("Area=",area)
# Out:
# Enter radius 10
# Area= 314.0

# %%
r = float(input("Enter radius"))

area = 3.14 * r**2
print("Area=",area)
# Out:
# Enter radius 12
# Area= 452.16

# %% [markdown]
# # 58. Difference: Bitwise vs Logical Operators

# %%
# logical operators 
# and or not
# work on true / false
# used in conditions

# bitwise operators

# &,|,^,~
# work on binary numbers
# used in bit manipulation


print(True and False or False)
print(4&1)
# Out:
# False
# 0

# %%
2**3**2
power is right le
# Out:
# 512

# %%
print((10+5)*2//3)
# 10 + 5 = 15
# 15 *2 = 30
# 30//10
# 10
# Out:
# 10
