# %% [markdown]
# # 1. What are operators in Python?

# %% [markdown]
# operators in python are special symbol used to perfrom operations on
# variable and values

# %% [markdown]
# # 2. What are arithmetic operators?

# %% [markdown]
# Arithmetic operators are used to perfrom mathematical
# calculations on numbers

# %%
# ex 
a = 10
b = 5

print(f"addition is {a+b}")
print(f" substraction is {a-b}")
print(f"multiplication is {a*b}")
print(f" division is {a/b}")
print(f" reminder is {a%b}")
print(f"floor division is {a//b}")
print(f"Exponent is {a**b}")
# Out:
# addition is 15
#  substraction is 5
# multiplication is 50
#  division is 2.0
#  reminder is 0
# floor division is 2
# Exponent is 100000

# %% [markdown]
# # 3. List all arithmetic operators in Python

# %% [markdown]
# There are 7 arithmetic operators in Python:
#
# + → Addition
#
# - → Subtraction
#
# * → Multiplication
#
# / → Division
#
# // → Floor Division
#
# % → Modulus (Remainder)
#
# ** → Exponent (Power)

# %% [markdown]
# # 4. What is the difference between / and //?

# %%
# / normal division 
# return the exact result in decimal 
# always gives output in float

# return the integer part only 
# removes the decimal part(round down to nearest whole num)

print(5/2)
print(5//2)
# Out:
# 2.5
# 2

# %% [markdown]
# # 5. What does the % operator do?

# %%
# the % opertor is called the modulus operator
# it returns the remainder after divison

print(10%3)
# Out:
# 1

# %% [markdown]
# # What is the output of: 5 + 3 * 2?

# %% [markdown]
# 5 + 3 * 2 # bodmas rule mul happens first

# %% [markdown]
# # What is the output of: 10 // 3?

# %%
10//3 # floor division removes the decimal part
# Out:
# 3

# %% [markdown]
# # 8.What is the output of: 10 % 3?

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# # 9. What is the result of: 2 ** 3?

# %%
2**3 # means power
# Out:
# 8

# %% [markdown]
# # 10. What are comparison operators?

# %% [markdown]
# comparison operators are used to compare two values
# they return true or false

# %% [markdown]
# # 11. List all comparison operators.

# %%
a = 10
b = 5

print(f" a is equal to b {a==b}")
print(f" a is not equal to b {a!=b}")
print(f" a is greater than to b {a>b}")
print(f" a is less than b {a<b}")
print(f" a is greater than or equal to b {a>=b}")
print(f" a is less than or equal to b {a<=b}")
# Out:
#  a is equal to b False
#  a is not equal to b True
#  a is greater than to b True
#  a is less than b False
#  a is greater than or equal to b True
#  a is less than or equal to b False

# %% [markdown]
# # 12. What is the output of: 5 > 3?

# %%
5 > 3
# Out:
# True

# %% [markdown]
# # 13. What is the output of: 5 == 5?

# %%
5 == 5
# Out:
# True

# %% [markdown]
# # 14. What is the difference between = and ==?

# %% [markdown]
# = assignment operator
# stores value
# example : x =10
#
# == comparision operator
# compares values
# ex = 5==5 True

# %% [markdown]
# # 15. What are logical operators?

# %% [markdown]
# logical operators are used to combine conditions
#
# and or not

# %% [markdown]
# # 16. What is the output of: True and False?

# %%
True and False # both must be true for and to return true
# Out:
# False

# %% [markdown]
# # 17. What is the output of: True or False?

# %%
True or False # at least one is true or returns true
# Out:
# True

# %% [markdown]
# # 18. What does the not operator do?

# %%
# it reverse the result
print(not True)
print(not False)
# Out:
# False
# True

# %% [markdown]
# # 19. What are assignment operators?

# %% [markdown]
# #  assignment opertaors are used to assign or update values
#  =
#
# +=
#
# -=
#
# *=
#
# /=
#
# //=
#
# %=
#
# **=

# %% [markdown]
# # 20 What is the output?

# %%
x = 5
x +=3

print(x)
# Out:
# 8
