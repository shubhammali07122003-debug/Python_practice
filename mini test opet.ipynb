# %% [markdown]
# # Arithmetic Operators

# %%
7 + 3 * 2
# Out:
# 13

# %%
20 // 6
# Out:
# 3

# %%
20 % 6
# Out:
# 2

# %%
3 ** 2 + 1
# Out:
# 10

# %%
-9 // 2
# Out:
# -5

# %% [markdown]
# # Comparison Operators

# %%
10 != 10
# Out:
# False

# %%
5 >= 3
# Out:
# True

# %%
4 < 2
# Out:
# False

# %% [markdown]
# # Logical Operators

# %%
True and True
# Out:
# True

# %%
not (5 > 3)
# Out:
# False

# %% [markdown]
# # Mixed Logic

# %%
5 > 3 and 2 < 1
# Out:
# False

# %%
(4 + 2) > 5
# Out:
# True

# %%
x = 4
x *= 3
x -= 2
print(x)
# Out:
# 10

# %%
print(True+True)
print(True+False)
print(False+False)
# Out:
# 2
# 1
# 0

# %%
True * 5
# Out:
# 5
